# %%
import scipy.io as spi
matfile = spi.loadmat('C:\\Users\\amir_\\Documents\\GitHub\\GradCompPhys\\MATLAB\\derdata.mat')
X=matfile['X'];
Y=matfile['Y'];

# %%
import numpy as np
x = np.linspace(-0.3,0.3,num=250)
import matplotlib.pyplot as pyp
from numpy import array

# %%
pyp.plot(X,Y)

# %%
dy = np.diff(Y,1,0)/np.diff(X,1,0)
pyp.plot(X[0:38],dy)

# %%
ddy = np.diff(np.diff(Y,1,0),1,0)/np.diff(np.diff(X,1,0),1,0)
pyp.plot(X[0:37],ddy)
